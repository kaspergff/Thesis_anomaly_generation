# %%
import pm4py
import pandas as pd
import csv

# %%
log = pd.read_csv('Production_Data.csv')
df = pm4py.convert_to_dataframe(log)

# %%
df.sort_values(['Case ID'])
df.head(50)
# Out:
#      Case ID                       Activity                       Resource  \
# 0     Case 1  Turning & Milling - Machine 4  Machine 4 - Turning & Milling
# 1     Case 1  Turning & Milling - Machine 4  Machine 4 - Turning & Milling
# 2     Case 1  Turning & Milling - Machine 4  Machine 4 - Turning & Milling
# 3     Case 1  Turning & Milling - Machine 4  Machine 4 - Turning & Milling
# 4     Case 1         Turning & Milling Q.C.                Quality Check 1
# 5     Case 1      Laser Marking - Machine 7       Machine 7- Laser Marking
# 6     Case 1            Lapping - Machine 1            Machine 1 - Lapping
# 7     Case 1            Lapping - Machine 1            Machine 1 - Lapping
# 8     Case 1            Lapping - Machine 1            Machine 1 - Lapping
# 9     Case 1            Lapping - Machine 1            Machine 1 - Lapping
# 10    Case 1     Round Grinding - Machine 3     Machine 3 - Round Grinding
# ...
