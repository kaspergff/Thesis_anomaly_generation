# %%
import pandas as pd
from collections import Counter
import numpy as np

# %%
base_df = pd.read_csv("BPI2016_Clicks_Logged_In.csv", encoding_errors="ignore", on_bad_lines='skip', sep=";",
                        usecols=[ 'CustomerID', 'AgeCategory', 'Gender', 'Office_U', 'Office_W',
                                  'SessionID', 'IPID', 'TIMESTAMP', 'VHOST', 'URL_FILE', 'PAGE_NAME',
                                  'REF_URL_category', 'page_load_error', 'page_action_detail', 'tip',
                                  'service_detail', 'xps_info'])
base_df.rename(columns={'URL_FILE':'Activity'}, inplace=True)
base_df["TIMESTAMP"] = pd.to_datetime(base_df["TIMESTAMP"], infer_datetime_format=True)
base_df = base_df.sort_values(["SessionID", "TIMESTAMP"])
# Out:
# C:\Users\krdeg\AppData\Local\Temp\ipykernel_20676\236448581.py:1: DtypeWarning: Columns (11,13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   base_df = pd.read_csv("BPI2016_Clicks_Logged_In.csv", encoding_errors="ignore", on_bad_lines='skip', sep=";",

# %%
# Helper functions
def create_df_for_pivot(df: pd.DataFrame):
  df = df.copy()
  #Create consecutive column with the consecutive activity and count how many time each pair occurs
  df["Consecutive_1"] = df.groupby("SessionID")["Activity"].shift(periods=-1)

  #Count all the pairs and safe in new DataFrame
  df_for_pivot_1 = pd.DataFrame(Counter(list(zip(df['Activity'], df['Consecutive_1'],))), index=["value"]).T.reset_index()

  df_for_pivot_1.fillna("end_session", inplace=True)
  return df_for_pivot_1
  
def make_pivot(df, index_names, column_names):
  df = df.copy()
  """
  Functions that takes in a DataFrame and returns a pivot table with all the chances
  
  Create pivot table where chances are calculated that each row is succeded by activity that is represented in the column
  """
  df_chances = df.pivot_table(index=index_names, columns=column_names, values='value')
  
  #Calculate what the probabilities are by summing the row and dividing all the values in the row by total sum of the row
  df_chances["total_row_count"] = df_chances.sum(axis=1)
  df_chances = df_chances.div(df_chances["total_row_count"], axis=0)
  
  df_chances.fillna(0, inplace=True)
  df_chances.drop("total_row_count", axis=1, inplace=True)

  return df_chances

  
# Create df for pivot
df_for_pivot = create_df_for_pivot(base_df)
df_chances_1 = make_pivot(df_for_pivot, "level_0", "level_1")

#Calculate the probability of each activity that it is the first activity performed in the session
df_chances_1["start_session_chance"] = base_df.groupby("SessionID").nth(0)["Activity"].value_counts() / base_df.groupby("SessionID").nth(0)["Activity"].value_counts().sum()
df_chances_1.fillna(0, inplace=True)

df_chances_total = df_chances_1 
df_chances_total

#Split the start probabilities from the normal DataFrame
start_chances = df_chances_total["start_session_chance"][df_chances_total["start_session_chance"] > 0]

#Create df with all chances except the starting chance.
final_df = df_chances_total.iloc[:, :-1]
final_df
probability_matrix = final_df.copy()

# %%
def find_paths_of_len_3(_df:pd.DataFrame):
  df = _df.copy()
  col = df.columns.values
  row  = df.index.values
  s  = row.size
  res = []
  while s > 0:
    current_row = df.iloc[row.size - s]
    i = 0
    while i < current_row.size:
      current_col = df.columns[i]
      chance = current_row.iloc[i]
      if chance > 0:
        a = current_row.name
        b = current_col
        
        if (df.index == b).any() :
          _r = df.loc[b]
          index = 0
          for r in _r:
            if r > 0:
              res.append({'a':a,'b':b,'c':col.item(index),"a-b-c":r*chance,"a-b":chance,"b-c":r})  
            index += 1        
            
      i += 1
    s -= 1

  return res

# %%
res = find_paths_of_len_3(probability_matrix)
res.sort(key=lambda x: x['a-b-c'], reverse=True)
len(res)
# Out:
# 1362220

# %%
# transform to dataframe
paths_df = pd.DataFrame(res)
# remove rows with a-b == 1
paths_df = paths_df[paths_df['a-b'] != 1]
# remove rows where a == b and where b == c and where a == c
paths_df = paths_df[paths_df['a'] != paths_df['b']]
paths_df = paths_df[paths_df['b'] != paths_df['c']]
paths_df = paths_df[paths_df['a'] != paths_df['c']]
# remove a row if the activity in a occurs only once in column a
paths_df = paths_df[paths_df['a'] != paths_df['a'].value_counts().index[0]]
# remove a row if the activity in c occurs only once in column c
paths_df = paths_df[paths_df['c'] != paths_df['c'].value_counts().index[0]]

# %%
paths_df
# Out:
#                                                          a  \
# 65       /werk_nl/werkgever/meerweten/ontslag/ontslagpr...
# 75       /werk_nl/werknemer/solliciteren/europa/land/no...
# 76       /werk_nl/werknemer/solliciteren/europa/land/oo...
# 80                                     /xpsimage/wdo211383
# 81                                    /xpsimage/wdo_011538
# ...                                                    ...
# 1362215     /portal/page/portal/home/diensten/aanvragen-ww
# 1362216     /portal/page/portal/home/diensten/aanvragen-ww
# 1362217     /portal/page/portal/home/diensten/aanvragen-ww
# 1362218     /portal/page/portal/home/diensten/aanvragen-ww
# 1362219     /portal/page/portal/home/diensten/aanvragen-ww
#
#                                                          b  \
# 65       /werk_nl/werkgever/meerweten/ontslag/ontslagve...
# 75       /werk_nl/werknemer/solliciteren/europa/land/le...
# 76       /werk_nl/werknemer/solliciteren/europa/land/ts...
# 80                                    /xpsimage/wdo_014540
# 81                                    /xpsimage/wdo_011537
# ...                                                    ...
# 1362215  /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...
# 1362216  /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...
# 1362217  /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...
# 1362218  /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...
# 1362219  /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...
#
#                                                          c         a-b-c  \
# 65                                 /werk_nl/werkgever/home  5.000000e-01
# 75       /werk_nl/werknemer/solliciteren/europa/land/zw...  5.000000e-01
# 76       /werk_nl/werknemer/solliciteren/europa/land/sl...  5.000000e-01
# 80                                    /xpsimage/wdo_011751  5.000000e-01
# 81                                    /xpsimage/wdo_013846  5.000000e-01
# ...                                                    ...           ...
# 1362215                               /xpsimage/wdo_011687  4.785496e-11
# 1362216                               /xpsimage/wdo_012890  4.785496e-11
# 1362217                                /xpsitem/ptl1716476  4.785496e-11
# 1362218                                /xpsitem/wdo_008957  4.785496e-11
# 1362219                                /xpsitem/wdo_010560  4.785496e-11
#
#               a-b       b-c
# 65       0.500000  1.000000
# 75       0.500000  1.000000
# 76       0.500000  1.000000
# 80       0.500000  1.000000
# 81       0.500000  1.000000
# ...           ...       ...
# 1362215  0.000028  0.000002
# 1362216  0.000028  0.000002
# 1362217  0.000028  0.000002
# 1362218  0.000028  0.000002
# 1362219  0.000028  0.000002
#
# [1288298 rows x 6 columns]

# %%
sorted = paths_df.sort_values(by=['a-b-c','a','c'], ascending=False)
tester = sorted.copy()

# %%
# create column that counts how many times the combination of the values in columns a and c occurs
tester = tester.sort_values(by=['a','c'], ascending=False)
tester
# Out:
#                                        a  \
# 741365   /zoeken_portlet/ajax/zoekBeroep
# 601066   /zoeken_portlet/ajax/zoekBeroep
# 27695    /zoeken_portlet/ajax/zoekBeroep
# 272496   /zoeken_portlet/ajax/zoekBeroep
# 344404   /zoeken_portlet/ajax/zoekBeroep
# ...                                  ...
# 1061762                                /
# 1182578                                /
# 714819                                 /
# 1080732                                /
# 1182577                                /
#
#                                                          b  \
# 741365                       /werk_nl/werkgever/cvs_zoeken
# 601066                       /werk_nl/werkgever/cvs_zoeken
# 27695                         /werk_nl/werknemer/vacatures
# 272496   /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...
# 344404                       /werk_nl/werkgever/cvs_zoeken
# ...                                                    ...
# 1061762  /werk_nl/werknemer/mijn_werkmap/postvak/mijn_d...
# 1182578  /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...
# 714819                             /werk_nl/werknemer/home
# 1080732  /werk_nl/werknemer/mijn_werkmap/doorgeven/wijz...
# 1182577  /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...
#
#                                                          c         a-b-c  \
# 741365              /zoeken_portlet_wg/ajax/selectVacature  7.070286e-07
# 601066        /zoeken_portlet_wg/ajax/selectContactpersoon  1.767571e-06
# 27695            /zoeken_portlet/ajax/zoekAantalIndicatief  3.049503e-03
# 272496           /zoeken_portlet/ajax/zoekAantalIndicatief  3.176599e-05
# 344404           /zoeken_portlet/ajax/zoekAantalIndicatief  1.484760e-05
# ...                                                    ...           ...
# 1061762  //portal/page/portal/werk_nl/werknemer/sollici...  1.178980e-07
# 1182578  //portal/page/portal/werk_nl/werknemer/sollici...  5.024011e-08
# 714819                                                  //  8.335844e-07
# 1080732                                                 //  1.046991e-07
# 1182577                                                 //  5.024011e-08
#
#               a-b       b-c
# 741365   0.000284  0.002488
# 601066   0.000284  0.006219
# 27695    0.039839  0.076546
# 272496   0.010374  0.003062
# 344404   0.000284  0.052239
# ...           ...       ...
# 1061762  0.016839  0.000007
# 1182578  0.047927  0.000001
# 714819   0.161917  0.000005
# 1080732  0.006477  0.000016
# 1182577  0.047927  0.000001
#
# [1288298 rows x 6 columns]

# %%
a_b_c = 0.1
to_be_replaced = sorted[sorted['a-b-c'] > a_b_c]
to_be_replaced
# Out:
#                                                      a  \
# 81                                /xpsimage/wdo_011538
# 80                                 /xpsimage/wdo211383
# 76   /werk_nl/werknemer/solliciteren/europa/land/oo...
# 75   /werk_nl/werknemer/solliciteren/europa/land/no...
# 65   /werk_nl/werkgever/meerweten/ontslag/ontslagpr...
# ..                                                 ...
# 810     /werk_nl/werkgever/meerweten/arbeidsrecht/loon
# 813                             /xdocs/css/AMI/PIE.htc
# 812  /werk_nl/arbeidsmarktinformatie/sector-beroep/...
# 821  /portal/page/portal/werk_nl/werknemer/sollicit...
# 822  /werk_nl/werknemer/solliciteren/europa/land/zw...
#
#                                                      b  \
# 81                                /xpsimage/wdo_011537
# 80                                /xpsimage/wdo_014540
# 76   /werk_nl/werknemer/solliciteren/europa/land/ts...
# 75   /werk_nl/werknemer/solliciteren/europa/land/le...
# 65   /werk_nl/werkgever/meerweten/ontslag/ontslagve...
# ..                                                 ...
# 810                                /xpsimage/wdo211830
# 813  /werk_nl/arbeidsmarktinformatie/sector-beroep/...
# 812        /werk_nl/arbeidsmarktinformatie/publicaties
# 821  /portal/page/portal/werk_nl/werknemer/sollicit...
# 822  /werk_nl/werknemer/solliciteren/ontwikkel-uzel...
#
#                                                      c     a-b-c       a-b  \
# 81                                /xpsimage/wdo_013846  0.500000  0.500000
# 80                                /xpsimage/wdo_011751  0.500000  0.500000
# 76   /werk_nl/werknemer/solliciteren/europa/land/sl...  0.500000  0.500000
# 75   /werk_nl/werknemer/solliciteren/europa/land/zw...  0.500000  0.500000
# 65                             /werk_nl/werkgever/home  0.500000  0.500000
# ..                                                 ...       ...       ...
# 810                    /werk_nl/werknemer/mijn_werkmap  0.104317  0.333333
# 813  /werk_nl/arbeidsmarktinformatie/sector-beroep/...  0.104167  0.333333
# 812                            /werk_nl/werknemer/home  0.104167  0.333333
# 821                                /xpsimage/WDO211980  0.102691  0.331522
# 822  /portal/page/portal/werk_nl/werknemer/sollicit...  0.102312  0.500000
#
#           b-c
# 81   1.000000
# 80   1.000000
# 76   1.000000
# 75   1.000000
# 65   1.000000
# ..        ...
# 810  0.312950
# 813  0.312500
# 812  0.312500
# 821  0.309756
# 822  0.204624
#
# [107 rows x 6 columns]

# %%
# for each row in to_be_replaced
# count how many rows in sorted have the same a and c
def count(a, c):
  return len(sorted[(sorted['a'] == a) & (sorted['c'] == c)])

to_be_replaced = to_be_replaced.assign(count=sorted.apply(lambda x: count(x['a'], x['c']), axis=1))
# remove rows where count == 1
to_be_replaced = to_be_replaced[to_be_replaced['count'] != 1]
# create a new column where all possibilities for b are saved in a list
to_be_replaced = to_be_replaced.assign(b_list=to_be_replaced.apply(lambda x: sorted[(sorted['a'] == x['a']) & (sorted['c'] == x['c'])]['b'].tolist(), axis=1))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 6
#       3 def count(a, c):
#       4   return len(sorted[(sorted['a'] == a) & (sorted['c'] == c)])
# ----> 6 to_be_replaced = to_be_replaced.assign(count=sorted.apply(lambda x: count(x['a'], x['c']), axis=1))
#       7 # remove rows where count == 1
#       8 to_be_replaced = to_be_replaced[to_be_replaced['count'] != 1]
#
# File c:\Python310\lib\site-packages\pandas\core\frame.py:8845, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8834 from pandas.core.apply import frame_apply
#    8836 op = frame_apply(
#    8837     self,
#    8838     func=func,
#    (...)
#    8843     kwargs=kwargs,
#    8844 )
# -> 8845 return op.apply().__finalize__(self, method="apply")
#
# File c:\Python310\lib\site-packages\pandas\core\apply.py:733, in FrameApply.apply(self)
#     730 elif self.raw:
#     731     return self.apply_raw()
# --> 733 return self.apply_standard()
#
# File c:\Python310\lib\site-packages\pandas\core\apply.py:857, in FrameApply.apply_standard(self)
#     856 def apply_standard(self):
# --> 857     results, res_index = self.apply_series_generator()
#     859     # wrap results
#     860     return self.wrap_results(results, res_index)
#
# File c:\Python310\lib\site-packages\pandas\core\apply.py:873, in FrameApply.apply_series_generator(self)
#     870 with option_context("mode.chained_assignment", None):
#     871     for i, v in enumerate(series_gen):
#     872         # ignore SettingWithCopy here in case the user mutates
# --> 873         results[i] = self.f(v)
#     874         if isinstance(results[i], ABCSeries):
#     875             # If we have a view on v, we need to make a copy because
#     876             #  series_generator will swap out the underlying data
#     877             results[i] = results[i].copy(deep=False)
#
# Cell In [11], line 6, in <lambda>(x)
#       3 def count(a, c):
#       4   return len(sorted[(sorted['a'] == a) & (sorted['c'] == c)])
# ----> 6 to_be_replaced = to_be_replaced.assign(count=sorted.apply(lambda x: count(x['a'], x['c']), axis=1))
#       7 # remove rows where count == 1
#       8 to_be_replaced = to_be_replaced[to_be_replaced['count'] != 1]
#
# Cell In [11], line 4, in count(a, c)
#       3 def count(a, c):
# ----> 4   return len(sorted[(sorted['a'] == a) & (sorted['c'] == c)])
#
# File c:\Python310\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File c:\Python310\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Python310\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# -> 5623     res_values = ops.comparison_op(lvalues, rvalues, op)
#    5625 return self._construct_result(res_values, name=res_name)
#
# File c:\Python310\lib\site-packages\pandas\core\ops\array_ops.py:283, in comparison_op(left, right, op)
#     280     return invalid_comparison(lvalues, rvalues, op)
#     282 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 283     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285 else:
#     286     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Python310\lib\site-packages\pandas\core\ops\array_ops.py:74, in comp_method_OBJECT_ARRAY(op, x, y)
#      72 else:
#      73     result = libops.scalar_compare(x.ravel(), y, op)
# ---> 74 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
to_be_replaced.sort_values(by=['count'], ascending=False)
# remove rows where count > 2
to_be_replaced = to_be_replaced[to_be_replaced['count'] <= 2]
# remove the value from b_list that is the same as b
to_be_replaced = to_be_replaced.assign(b_list=to_be_replaced.apply(lambda x: [i for i in x['b_list'] if i != x['b']], axis=1))
to_be_replaced
# Out:
#                                                      a  \
# 65   /werk_nl/werkgever/meerweten/ontslag/ontslagpr...
# 149  /werk_nl/werknemer/contact/werkplein/routebesc...
# 136  /portal/page/portal/werk_nl/werknemer/ontslag/...
# 248  /werk_nl/werkgever/wervingsadvies/werkgeversse...
# 349  /werk_nl/arbeidsmarktinformatie/publicaties/th...
# 379                            /werk_nl/werkgever/over
# 437  /werk_nl/werkgever/direct_naar/WerkgeversServi...
# 435        /werk_nl/arbeidsmarktinformatie/sector/Zorg
# 434  /werk_nl/arbeidsmarktinformatie/sector-beroep/...
# 426  /portal/page/portal/werk_nl/werknemer/ontslag/...
# 448  /werk_nl/werknemer/solliciteren/ontwikkel-uzel...
# 469                            /werk_nl/werkgever/over
# 473  /werk_nl/arbeidsmarktinformatie/sector/welzijn...
# 573  //werk_nl/werknemer/solliciteren/test/kansverk...
# 591                    /werk_nl/werknemer/melding_sha2
# 608  //werk_nl/werknemer/solliciteren/test/kansverk...
# 637  /werk_nl/arbeidsmarktinformatie/sector-beroep/...
# 610  /werk_nl/arbeidsmarktinformatie/achtergrond/ar...
# 655  /werk_nl/werknemer/uitkering-aanvragen/disclaimer
# 661       /portal/page/portal/werk_nl/werkgever/zoeken
# 675                               /xpsimage/wdo_013404
# 736  /werk_nl/arbeidsmarktinformatie/sector-beroep/...
# 810     /werk_nl/werkgever/meerweten/arbeidsrecht/loon
#
#                                                      b  \
# 65   /werk_nl/werkgever/meerweten/ontslag/ontslagve...
# 149                                /xpsitem/ptl1716628
# 136  /werk_nl/werkgever/meerweten/ontslag/redenen/b...
# 248  /werk_nl/werkgever/wervingsadvies/werkgeversse...
# 349  /werk_nl/arbeidsmarktinformatie/publicaties/th...
# 379                         /werk_nl/werknemer/werkmap
# 437  /werk_nl/werkgever/direct_naar/formulieren_dow...
# 435  /werk_nl/arbeidsmarktinformatie/sector/welzijn...
# 434  /werk_nl/arbeidsmarktinformatie/sector-beroep/...
# 426  /werk_nl/werkgever/meerweten/ontslag/opzegtermijn
# 448  /portal/page/portal/werk_nl/werknemer/sollicit...
# 469                            /werk_nl/werkgever/home
# 473        /werk_nl/arbeidsmarktinformatie/publicaties
# 573  /werk_nl/werknemer/solliciteren/test/kansverke...
# 591                            /werk_nl/werknemer/home
# 608  /ajax/dwr/call/plaincall/JBeroepenFinder.searc...
# 637  /werk_nl/arbeidsmarktinformatie/sector-beroep/...
# 610  /werk_nl/arbeidsmarktinformatie/achtergrond/to...
# 655                 /werk_nl/werknemer/gegevens-inzien
# 661                         /werk_nl/werknemer/werkmap
# 675  /werk_nl/werknemer/mijn_werkmap/mijn-weg-naar-...
# 736  /werk_nl/arbeidsmarktinformatie/sector-beroep/...
# 810                                /xpsimage/wdo211830
#
#                                                      c     a-b-c       a-b  \
# 65                             /werk_nl/werkgever/home  0.500000  0.500000
# 149                            /werk_nl/werknemer/home  0.333333  0.333333
# 136                                /xpsimage/wdo211832  0.333333  0.333333
# 248  /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...  0.250000  0.500000
# 349                            /werk_nl/werknemer/home  0.200000  0.200000
# 379    /werk_nl/werknemer/mijn_werkmap/doorgeven/taken  0.183900  0.500000
# 437                            /werk_nl/werkgever/home  0.166667  0.500000
# 435        /werk_nl/arbeidsmarktinformatie/publicaties  0.166667  0.333333
# 434                            /werk_nl/werknemer/home  0.166667  0.333333
# 426                            /werk_nl/werknemer/home  0.166667  0.333333
# 448                                /xpsimage/wdo211602  0.165732  0.532710
# 469                            /werk_nl/werknemer/home  0.158433  0.500000
# 473                            /werk_nl/werknemer/home  0.156250  0.500000
# 573  /ajax/dwr/call/plaincall/JBeroepenFinder.searc...  0.134684  0.333333
# 591    /werk_nl/werknemer/mijn_werkmap/doorgeven/taken  0.128644  0.833333
# 608  /werk_nl/werknemer/solliciteren/test/kansverke...  0.125137  0.333333
# 637           /werk_nl/arbeidsmarktinformatie/tabellen  0.125000  0.500000
# 610        /werk_nl/arbeidsmarktinformatie/achtergrond  0.125000  0.500000
# 655         /portal/page/portal/home/diensten/gegevens  0.124663  0.166667
# 661    /werk_nl/werknemer/mijn_werkmap/doorgeven/taken  0.122600  0.333333
# 675    /werk_nl/werknemer/mijn_werkmap/doorgeven/taken  0.117417  0.500000
# 736        /werk_nl/arbeidsmarktinformatie/publicaties  0.111111  0.333333
# 810                    /werk_nl/werknemer/mijn_werkmap  0.104317  0.333333
#
#           b-c  count                                             b_list  \
# 65   1.000000      2        [/werk_nl/werknemer/uitkering-aanvragen/ww]
# 149  1.000000      2  [/werk_nl/werknemer/ontslag/wederzijds-goedvin...
# 136  1.000000      2                  [/werk_nl/werknemer/mijn_werkmap]
# 248  0.500000      2                          [/werk_nl/werknemer/home]
# 349  1.000000      2             [/werk_nl/arbeidsmarktinformatie/home]
# 379  0.367800      2                          [/werk_nl/werkgever/home]
# 437  0.333333      2             [/werk_nl/werkgever/meerweten/werving]
# 435  0.500000      2            [/werk_nl/arbeidsmarktinformatie/regio]
# 434  0.500000      2             [/werk_nl/arbeidsmarktinformatie/home]
# 426  0.500000      2                       [/werk_nl/werknemer/ontslag]
# 448  0.311111      2  [/portal/page/portal/werk_nl/werknemer/sollici...
# 469  0.316865      2                       [/werk_nl/werknemer/werkmap]
# 473  0.312500      2         [/werk_nl/arbeidsmarktinformatie/tabellen]
# 573  0.404051      2  [/werk_nl/werknemer/mijn_werkmap/postvak/mijn_...
# 591  0.154373      2  [/portal/pls/portal/PORTAL.wwsbr_javascript.pa...
# 608  0.375412      2  [/werk_nl/werknemer/mijn_werkmap/postvak/mijn_...
# 637  0.250000      2                          [/werk_nl/werknemer/home]
# 610  0.250000      2         [/werk_nl/arbeidsmarktinformatie/tabellen]
# 655  0.747976      2           [/werk_nl/werknemer/uitkering-aanvragen]
# 661  0.367800      2  [/werk_nl/werknemer/over-werk-nl/handleiding/c...
# 675  0.234834      2  [/werk_nl/werknemer/mijn_werkmap/werk-zoeken/m...
# 736  0.333333      2             [/werk_nl/arbeidsmarktinformatie/home]
# 810  0.312950      2  [/werk_nl/werknemer/mijn_werkmap/postvak/mijn_...
#
#      b_list_len
# 65            2
# 149           2
# 136           2
# 248           2
# 349           2
# 379           2
# 437           2
# 435           2
# 434           2
# 426           2
# 448           2
# 469           2
# 473           2
# 573           2
# 591           2
# 608           2
# 637           2
# 610           2
# 655           2
# 661           2
# 675           2
# 736           2
# 810           2
