# %%
import pandas as pd
from collections import Counter
import numpy as np

# %%
# base_df = pd.read_csv("../no_repeated.csv", encoding_errors="ignore", on_bad_lines='skip', sep=",",)
base_df = pd.read_csv("../BPI2016_Clicks_Logged_In.csv", encoding_errors="ignore", on_bad_lines='skip', sep=";",usecols=['SessionID', 'TIMESTAMP', 'URL_FILE', ])
base_df.rename(columns={'URL_FILE':'Activity'}, inplace=True)
base_df["TIMESTAMP"] = pd.to_datetime(base_df["TIMESTAMP"], infer_datetime_format=True)
base_df = base_df.sort_values(["SessionID", "TIMESTAMP"])
base_df.head()
# Out:
#          SessionID               TIMESTAMP  \
# 3273278         46 2015-11-06 08:07:22.780
# 5333642         46 2015-11-06 08:07:40.767
# 3733243         46 2015-11-06 08:07:51.390
# 5904405         46 2015-11-06 08:08:06.003
# 5573282         46 2015-11-06 08:08:19.343
#
#                                                   Activity
# 3273278    /werk_nl/werknemer/mijn_werkmap/doorgeven/taken
# 5333642  /werk_nl/werknemer/mijn_werkmap/doorgeven/mijn...
# 3733243  /werk_nl/werknemer/mijn_werkmap/postvak/mijn_d...
# 5904405  /werk_nl/werknemer/mijn_werkmap/postvak/mijn_b...
# 5573282  /werk_nl/werknemer/mijn_werkmap/postvak/mijn_b...

# %%
# Helper functions
def create_df_for_pivot(_df: pd.DataFrame):
  df = _df.copy()
  #Create consecutive column with the consecutive activity and count how many time each pair occurs
  df["Consecutive_1"] = df.groupby("SessionID")["Activity"].shift(periods=-1)

  #Count all the pairs and safe in new DataFrame
  df_for_pivot_1 = pd.DataFrame(Counter(list(zip(df['Activity'], df['Consecutive_1'],))), index=["value"]).T.reset_index()

  df_for_pivot_1.fillna("end_session", inplace=True)
  return df_for_pivot_1
  
  
def make_pivot(_df, index_names, column_names):
  df = _df.copy()
  """
  Functions that takes in a DataFrame and returns a pivot table with all the chances
  
  Create pivot table where chances are calculated that each row is succeded by activity that is represented in the column
  """
  df_chances = df.pivot_table(index=index_names, columns=column_names, values='value')
  
  #Calculate what the probabilities are by summing the row and dividing all the values in the row by total sum of the row
  df_chances["total_row_count"] = df_chances.sum(axis=1)
  df_chances = df_chances.div(df_chances["total_row_count"], axis=0)
  
  df_chances.fillna(0, inplace=True)
  df_chances.drop("total_row_count", axis=1, inplace=True)

  return df_chances

def calculate_paths_in_sessions(_df:pd.DataFrame,paths:list[str]) -> tuple[int,int]:
  # this function calculates in how many sessions a path is present
  # a path is a series of transitions
  # a transition is two consecutive activities where the 2 activities are not the same
  # we return a tuple where the first value is the total amount of times the path is found and
  # the second value is the total amount of sessions where the path is found
  # group the dataframe by session id
  df = _df.copy()
  # create a new column that contains the consecutive activity
  df["Consecutive_1"] = df.groupby("SessionID")["Activity"].shift(periods=-1)
  # if the consecutive activity is the same as the current activity, remove the row
  # this is done because we only want to count transitions
  df = df[df["Activity"] != df["Consecutive_1"]]
  # remove the consecutive activity column
  df = df.drop("Consecutive_1", axis=1)
  # get the length of the path
  len_path = len(paths)
  # create a column for len_path - 1 consecutive activities
  df = df.assign(**{f"Activity_{i}": df.groupby("SessionID")["Activity"].shift(periods=-i) for i in range(1, len_path)})
  # change name of Activiy column to Activity_0
  df.rename(columns={'Activity':'Activity_0'}, inplace=True)
  # create a column "Found" that contains True if the path is found in the session
  df['Found'] = df.apply(lambda row: all(row[f"Activity_{i}"] == paths[i] for i in range(len_path)), axis=1)
  total = df['Found'].sum()
  sessions = df[df['Found'] == True]['SessionID'].nunique()
  return total,sessions


def all_paths_len_x(_df:pd.DataFrame,len):
  df = _df.copy()
  df["Consecutive_1"] = df.groupby("SessionID")["Activity"].shift(periods=-1)
  # if the consecutive activity is the same as the current activity, remove the row
  # this is done because we only want to count transitions
  df = df[df["Activity"] != df["Consecutive_1"]]
  # remove the consecutive activity column
  df = df.drop("Consecutive_1", axis=1)
  # create a column for len_path - 1 consecutive activities
  df = df.assign(**{f"Activity_{i}": df.groupby("SessionID")["Activity"].shift(periods=-i) for i in range(1, len)})
  # change name of Activiy column to Activity_0
  df.rename(columns={'Activity':'Activity_0'}, inplace=True)
  # create a column that counts the amount of times the path is found
  df = df.groupby([f"Activity_{i}" for i in range(len)]).size().reset_index(name='count')
  total_count = df['count'].sum()
  df['probability'] = df['count'] / total_count
  return df
  
  

def activity_prob_df(_df:pd.DataFrame) -> pd.DataFrame:
  # group the dataframe by activity and count the number of times each activity occurs
  df = _df.copy()
  total_amount_of_activities = df['Activity'].count()
  # create df where each row contains the activity with columns: Activity, Count, Probability
  final_df = df.groupby('Activity').count().reset_index()
  # Drop column Timestamp
  final_df = final_df.drop('TIMESTAMP', axis=1)
  # change SessionID column name to Count
  final_df.rename(columns={'SessionID':'Count'}, inplace=True)
  # create Probability column
  final_df = final_df.assign(Probability=final_df['Count']/total_amount_of_activities * 100)
  
  return final_df.sort_values('Probability', ascending=False)

# %%
# Create df for pivot
df_for_pivot = create_df_for_pivot(base_df)
df_chances_1 = make_pivot(df_for_pivot, "level_0", "level_1")

#Calculate the probability of each activity that it is the first activity performed in the session
df_chances_1["start_session_chance"] = base_df.groupby("SessionID").nth(0)["Activity"].value_counts() / base_df.groupby("SessionID").nth(0)["Activity"].value_counts().sum()
df_chances_1.fillna(0, inplace=True)

df_chances_total = df_chances_1 
df_chances_total

#Split the start probabilities from the normal DataFrame
start_chances = df_chances_total["start_session_chance"][df_chances_total["start_session_chance"] > 0]

#Create df with all chances except the starting chance.
final_df = df_chances_total.iloc[:, :-1]
final_df
probability_matrix = final_df.copy()

# %%
paths_len_2 = all_paths_len_x(base_df,2)
paths_len_2_2 = all_paths_len_x(base_df,2)

# %%
work_df_1 = paths_len_2.sort_values('count', ascending=False)
work_df_2 = paths_len_2_2.copy()

# %%
merged = pd.merge(work_df_1, work_df_2, left_on=['Activity_0','Activity_1'], right_on=['Activity_1','Activity_0'], how='inner')
merged
# Out:
#                                            Activity_0_x  \
# 0       /werk_nl/werknemer/mijn_werkmap/doorgeven/taken
# 1       /werk_nl/werknemer/mijn_werkmap/doorgeven/taken
# 2     /werk_nl/werknemer/mijn_werkmap/doorgeven/mijn...
# 3                               /werk_nl/werknemer/home
# 4                            /werk_nl/werknemer/werkmap
# ...                                                 ...
# 8539    /werk_nl/werknemer/mijn_werkmap/tip-van-de-week
# 8540    /werk_nl/werknemer/mijn_werkmap/tip-van-de-week
# 8541    /werk_nl/werknemer/mijn_werkmap/tip-van-de-week
# 8542    /werk_nl/werknemer/mijn_werkmap/tip-van-de-week
# 8543  /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...
#
#                                            Activity_1_x  count_x  \
# 0     /werk_nl/werknemer/mijn_werkmap/doorgeven/mijn...   123143
# 1                               /werk_nl/werknemer/home   118348
# 2       /werk_nl/werknemer/mijn_werkmap/doorgeven/taken    95763
# 3       /werk_nl/werknemer/mijn_werkmap/doorgeven/taken    89957
# 4       /werk_nl/werknemer/mijn_werkmap/doorgeven/taken    66648
# ...                                                 ...      ...
# 8539  /werk_nl/werknemer/uitkering-aanvragen/uwv-die...        1
# 8540  /werk_nl/werknemer/solliciteren/solliciteren-w...        1
# 8541                    /werk_nl/werknemer/over-werk-nl        1
# 8542                       /werk_nl/ignore_request_page        1
# 8543  /werk_nl/werknemer/solliciteren/ontwikkel-uzel...        1
#
#       probability_x                                       Activity_0_y  \
# 0      5.336082e-02  /werk_nl/werknemer/mijn_werkmap/doorgeven/mijn...
# 1      5.128303e-02                            /werk_nl/werknemer/home
# 2      4.149641e-02    /werk_nl/werknemer/mijn_werkmap/doorgeven/taken
# 3      3.898053e-02    /werk_nl/werknemer/mijn_werkmap/doorgeven/taken
# 4      2.888018e-02    /werk_nl/werknemer/mijn_werkmap/doorgeven/taken
# ...             ...                                                ...
# 8539   4.333240e-07  /werk_nl/werknemer/uitkering-aanvragen/uwv-die...
# 8540   4.333240e-07  /werk_nl/werknemer/solliciteren/solliciteren-w...
# 8541   4.333240e-07                    /werk_nl/werknemer/over-werk-nl
# 8542   4.333240e-07                       /werk_nl/ignore_request_page
# 8543   4.333240e-07  /werk_nl/werknemer/solliciteren/ontwikkel-uzel...
#
#                                            Activity_1_y  count_y  \
# 0       /werk_nl/werknemer/mijn_werkmap/doorgeven/taken    95763
# 1       /werk_nl/werknemer/mijn_werkmap/doorgeven/taken    89957
# 2     /werk_nl/werknemer/mijn_werkmap/doorgeven/mijn...   123143
# 3                               /werk_nl/werknemer/home   118348
# 4                            /werk_nl/werknemer/werkmap     4314
# ...                                                 ...      ...
# 8539    /werk_nl/werknemer/mijn_werkmap/tip-van-de-week        1
# 8540    /werk_nl/werknemer/mijn_werkmap/tip-van-de-week        2
# 8541    /werk_nl/werknemer/mijn_werkmap/tip-van-de-week        1
# 8542    /werk_nl/werknemer/mijn_werkmap/tip-van-de-week        3
# 8543  /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...        2
#
#       probability_y
# 0      4.149641e-02
# 1      3.898053e-02
# 2      5.336082e-02
# 3      5.128303e-02
# 4      1.869360e-03
# ...             ...
# 8539   4.333240e-07
# 8540   8.666480e-07
# 8541   4.333240e-07
# 8542   1.299972e-06
# 8543   8.666480e-07
#
# [8544 rows x 8 columns]

# %%
merged = merged.drop(['Activity_1_y','Activity_0_y','probability_y','probability_x'], axis=1)

# %%
merged['dif'] = merged['count_x'] - merged['count_y']
merged['fac'] = merged['count_x'] / merged['count_y']
merged.sort_values('fac', ascending=False)
merged_df = merged[merged['fac'] > 40]
len(merged_df)
merged_df
# Out:
#                                            Activity_0_x  \
# 88      /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 97                                  /shared/timeout.htm
# 179     /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 222              /werk_nl/werknemer/uitkering-aanvragen
# 232     /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 237      /xdocs/ux-frontend/fonts/uwvsanlig-webfont.eot
# 314   /portal/page/portal/werk_nl/werknemer/uitkerin...
# 366   /werk_nl/werknemer/mijn_werkmap/doorgeven/wijz...
# 371     /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 379     /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 451     /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 454                     /werk_nl/werknemer/solliciteren
# 457       /werk_nl/werknemer/solliciteren/eigen-bedrijf
# 483      /xdocs/ux-frontend/fonts/uwvsanlig-webfont.eot
# 514     /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 534                               /ewerkmap/readdetails
# 604     /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 677         /werk_nl/werknemer/over-werk-nl/handleiding
# 696                        /werk_nl/ignore_request_page
# 699                                  /ewerkmap/document
# 703         /werk_nl/werknemer/over-werk-nl/handleiding
# 707   /werk_nl/werknemer/solliciteren/solliciteren-w...
# 715                                /queueit/healthcheck
# 736                        /werk_nl/ignore_request_page
# 770         /werk_nl/werknemer/over-werk-nl/handleiding
# 780              /werk_nl/werknemer/uitkering-aanvragen
# 819           /zoeken_portlet/ajax/zoekAantalIndicatief
# 843      /xdocs/ux-frontend/fonts/uwvsanlig-webfont.eot
# 849      /xdocs/ux-frontend/fonts/uwvsanlig-webfont.eot
# 858      /portal/page/portal/home/diensten/aanvragen-ww
# 895                                 /xpsimage/wdo213133
# 921              /werk_nl/werknemer/uitkering-aanvragen
# 929       /werk_nl/werknemer/solliciteren/eigen-bedrijf
# 949                               /ewerkmap/readdetails
# 1000  /werk_nl/werknemer/over-werk-nl/handleiding/va...
# 1003                                /printservice/print
# 1067  /portal/page/portal/werk_nl/werknemer/sollicit...
# 1124                        //werk_nl/werknemer/werkmap
# 1143  /werk_nl/werknemer/over-werk-nl/handleiding/so...
# 1148                                 /ewerkmap/document
# 1170                                /xpsimage/WDO211559
# 1196                         /werk_nl/werknemer/werkmap
# 1220  /portal/page/portal/werk_nl/werknemer/sollicit...
# 1234                    /werk_nl/werknemer/solliciteren
# 1251  /werk_nl/werknemer/mijn_werkmap/mijn-weg-naar-...
# 1265                         /werk_nl/werknemer/contact
# 1290                         /werk_nl/werknemer/werkmap
# 1327  /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...
# 1349                         /werk_nl/werknemer/werkmap
# 1361  /portal/page/portal/werk_nl/werknemer/sollicit...
# 1362  /werk_nl/werknemer/mijn_werkmap/inschrijving/m...
# 1366  /portal/page/portal/werk_nl/werknemer/sollicit...
# 1381  /portal/page/portal/werk_nl/werknemer/sollicit...
#
#                                            Activity_1_x  count_x  count_y  \
# 88      /werk_nl/werknemer/mijn_werkmap/doorgeven/taken     4330        8
# 97                              /werk_nl/werknemer/home     3799       43
# 179   /werk_nl/werknemer/mijn_werkmap/postvak/mijn_b...     1556        3
# 222   /portal/page/portal/werk_nl/werknemer/uitkerin...     1077       10
# 232   /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...     1021        5
# 237     /werk_nl/werknemer/mijn_werkmap/doorgeven/taken      979        1
# 314      /portal/page/portal/home/diensten/aanvragen-ww      581       14
# 366                             /werk_nl/werknemer/home      433        1
# 371                     /werk_nl/werknemer/mijn_werkmap      422        4
# 379   /werk_nl/werknemer/mijn_werkmap/doorgeven/mijn...      401        2
# 451   /werk_nl/werknemer/mijn_werkmap/werk-zoeken/mi...      306        1
# 454   /portal/page/portal/werk_nl/werknemer/sollicit...      303        3
# 457   /portal/page/portal/werk_nl/werknemer/sollicit...      301        5
# 483   /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...      265        2
# 514   /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...      236        2
# 534   /werk_nl/werknemer/mijn_werkmap/doorgeven/mijn...      214        4
# 604   /werk_nl/werknemer/mijn_werkmap/postvak/mijn_d...      176        2
# 677   /portal/page/portal/werk_nl/werknemer/over-wer...      142        2
# 696                         /shared/foutopgetreden.html      135        3
# 699     /werk_nl/werknemer/mijn_werkmap/doorgeven/taken      134        2
# 703   /portal/page/portal/werk_nl/werknemer/over-wer...      133        3
# 707                                 /xpsimage/WDO212444      132        3
# 715     /werk_nl/werknemer/mijn_werkmap/doorgeven/taken      131        2
# 736                                 /shared/timeout.htm      124        1
# 770   /portal/page/portal/werk_nl/werknemer/over-wer...      115        2
# 780   /portal/page/portal/werk_nl/werknemer/uitkerin...      111        2
# 819                         /shared/foutopgetreden.html      103        2
# 843                     /werk_nl/werknemer/mijn_werkmap       99        1
# 849   /werk_nl/werknemer/mijn_werkmap/werk-zoeken/mi...       97        1
# 858                                  /werk_nl/werknemer       95        2
# 895                     /werk_nl/werknemer/mijn_werkmap       89        2
# 921   /portal/page/portal/werk_nl/werknemer/uitkerin...       82        2
# 929   /portal/page/portal/werk_nl/werknemer/sollicit...       80        1
# 949   /werk_nl/werknemer/mijn_werkmap/doorgeven/take...       77        1
# 1000                    /werk_nl/werknemer/mijn_werkmap       71        1
# 1003                         /werk_nl/werknemer/werkmap       71        1
# 1067                            /werk_nl/werknemer/home       63        1
# 1124    /werk_nl/werknemer/mijn_werkmap/doorgeven/taken       57        1
# 1143                    /werk_nl/werknemer/over-werk-nl       55        1
# 1148  /werk_nl/werknemer/mijn_werkmap/werk-zoeken/mi...       55        1
# 1170          /werk_nl/werknemer/uitkering-aanvragen/ww       53        1
# 1196    /werk_nl/werknemer/mijn_werkmap/tip-van-de-week       52        1
# 1220  /werk_nl/werknemer/solliciteren/solliciteren-w...       50        1
# 1234  /portal/page/portal/werk_nl/werknemer/sollicit...       50        1
# 1251  /werk_nl/werknemer/mijn_werkmap/inschrijving/m...       49        1
# 1265          /werk_nl/werknemer/contact/email_uw_vraag       47        1
# 1290         /portal/pls/portal/!PORTAL.wwpob_smd.login       46        1
# 1327                               /xpsimage/wdo_014546       44        1
# 1349  /werk_nl/werknemer/solliciteren/ontwikkel-uzel...       42        1
# 1361  /werk_nl/werknemer/solliciteren/solliciteren-w...       42        1
# 1362  /werk_nl/werknemer/mijn_werkmap/postvak/mijn_b...       42        1
# 1366                            /werk_nl/werknemer/home       41        1
# 1381  /werk_nl/werknemer/solliciteren/ontwikkel-uzel...       41        1
#
#        dif         fac
# 88    4322  541.250000
# 97    3756   88.348837
# 179   1553  518.666667
# 222   1067  107.700000
# 232   1016  204.200000
# 237    978  979.000000
# 314    567   41.500000
# 366    432  433.000000
# 371    418  105.500000
# 379    399  200.500000
# 451    305  306.000000
# 454    300  101.000000
# 457    296   60.200000
# 483    263  132.500000
# 514    234  118.000000
# 534    210   53.500000
# 604    174   88.000000
# 677    140   71.000000
# 696    132   45.000000
# 699    132   67.000000
# 703    130   44.333333
# 707    129   44.000000
# 715    129   65.500000
# 736    123  124.000000
# 770    113   57.500000
# 780    109   55.500000
# 819    101   51.500000
# 843     98   99.000000
# 849     96   97.000000
# 858     93   47.500000
# 895     87   44.500000
# 921     80   41.000000
# 929     79   80.000000
# 949     76   77.000000
# 1000    70   71.000000
# 1003    70   71.000000
# 1067    62   63.000000
# 1124    56   57.000000
# 1143    54   55.000000
# 1148    54   55.000000
# 1170    52   53.000000
# 1196    51   52.000000
# 1220    49   50.000000
# 1234    49   50.000000
# 1251    48   49.000000
# 1265    46   47.000000
# 1290    45   46.000000
# 1327    43   44.000000
# 1349    41   42.000000
# 1361    41   42.000000
# 1362    41   42.000000
# 1366    40   41.000000
# 1381    40   41.000000

# %%
patters_df = merged_df.copy()

# %%
patters_df
# Out:
#                                            Activity_0_x  \
# 88      /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 97                                  /shared/timeout.htm
# 179     /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 222              /werk_nl/werknemer/uitkering-aanvragen
# 232     /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 237      /xdocs/ux-frontend/fonts/uwvsanlig-webfont.eot
# 314   /portal/page/portal/werk_nl/werknemer/uitkerin...
# 366   /werk_nl/werknemer/mijn_werkmap/doorgeven/wijz...
# 371     /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 379     /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 451     /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 454                     /werk_nl/werknemer/solliciteren
# 457       /werk_nl/werknemer/solliciteren/eigen-bedrijf
# 483      /xdocs/ux-frontend/fonts/uwvsanlig-webfont.eot
# 514     /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 534                               /ewerkmap/readdetails
# 604     /xdocs/ux-frontend/fonts/uwvsanlig-webfont.woff
# 677         /werk_nl/werknemer/over-werk-nl/handleiding
# 696                        /werk_nl/ignore_request_page
# 699                                  /ewerkmap/document
# 703         /werk_nl/werknemer/over-werk-nl/handleiding
# 707   /werk_nl/werknemer/solliciteren/solliciteren-w...
# 715                                /queueit/healthcheck
# 736                        /werk_nl/ignore_request_page
# 770         /werk_nl/werknemer/over-werk-nl/handleiding
# 780              /werk_nl/werknemer/uitkering-aanvragen
# 819           /zoeken_portlet/ajax/zoekAantalIndicatief
# 843      /xdocs/ux-frontend/fonts/uwvsanlig-webfont.eot
# 849      /xdocs/ux-frontend/fonts/uwvsanlig-webfont.eot
# 858      /portal/page/portal/home/diensten/aanvragen-ww
# 895                                 /xpsimage/wdo213133
# 921              /werk_nl/werknemer/uitkering-aanvragen
# 929       /werk_nl/werknemer/solliciteren/eigen-bedrijf
# 949                               /ewerkmap/readdetails
# 1000  /werk_nl/werknemer/over-werk-nl/handleiding/va...
# 1003                                /printservice/print
# 1067  /portal/page/portal/werk_nl/werknemer/sollicit...
# 1124                        //werk_nl/werknemer/werkmap
# 1143  /werk_nl/werknemer/over-werk-nl/handleiding/so...
# 1148                                 /ewerkmap/document
# 1170                                /xpsimage/WDO211559
# 1196                         /werk_nl/werknemer/werkmap
# 1220  /portal/page/portal/werk_nl/werknemer/sollicit...
# 1234                    /werk_nl/werknemer/solliciteren
# 1251  /werk_nl/werknemer/mijn_werkmap/mijn-weg-naar-...
# 1265                         /werk_nl/werknemer/contact
# 1290                         /werk_nl/werknemer/werkmap
# 1327  /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...
# 1349                         /werk_nl/werknemer/werkmap
# 1361  /portal/page/portal/werk_nl/werknemer/sollicit...
# 1362  /werk_nl/werknemer/mijn_werkmap/inschrijving/m...
# 1366  /portal/page/portal/werk_nl/werknemer/sollicit...
# 1381  /portal/page/portal/werk_nl/werknemer/sollicit...
#
#                                            Activity_1_x  count_x  count_y  \
# 88      /werk_nl/werknemer/mijn_werkmap/doorgeven/taken     4330        8
# 97                              /werk_nl/werknemer/home     3799       43
# 179   /werk_nl/werknemer/mijn_werkmap/postvak/mijn_b...     1556        3
# 222   /portal/page/portal/werk_nl/werknemer/uitkerin...     1077       10
# 232   /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...     1021        5
# 237     /werk_nl/werknemer/mijn_werkmap/doorgeven/taken      979        1
# 314      /portal/page/portal/home/diensten/aanvragen-ww      581       14
# 366                             /werk_nl/werknemer/home      433        1
# 371                     /werk_nl/werknemer/mijn_werkmap      422        4
# 379   /werk_nl/werknemer/mijn_werkmap/doorgeven/mijn...      401        2
# 451   /werk_nl/werknemer/mijn_werkmap/werk-zoeken/mi...      306        1
# 454   /portal/page/portal/werk_nl/werknemer/sollicit...      303        3
# 457   /portal/page/portal/werk_nl/werknemer/sollicit...      301        5
# 483   /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...      265        2
# 514   /werk_nl/werknemer/mijn_werkmap/werk-zoeken/va...      236        2
# 534   /werk_nl/werknemer/mijn_werkmap/doorgeven/mijn...      214        4
# 604   /werk_nl/werknemer/mijn_werkmap/postvak/mijn_d...      176        2
# 677   /portal/page/portal/werk_nl/werknemer/over-wer...      142        2
# 696                         /shared/foutopgetreden.html      135        3
# 699     /werk_nl/werknemer/mijn_werkmap/doorgeven/taken      134        2
# 703   /portal/page/portal/werk_nl/werknemer/over-wer...      133        3
# 707                                 /xpsimage/WDO212444      132        3
# 715     /werk_nl/werknemer/mijn_werkmap/doorgeven/taken      131        2
# 736                                 /shared/timeout.htm      124        1
# 770   /portal/page/portal/werk_nl/werknemer/over-wer...      115        2
# 780   /portal/page/portal/werk_nl/werknemer/uitkerin...      111        2
# 819                         /shared/foutopgetreden.html      103        2
# 843                     /werk_nl/werknemer/mijn_werkmap       99        1
# 849   /werk_nl/werknemer/mijn_werkmap/werk-zoeken/mi...       97        1
# 858                                  /werk_nl/werknemer       95        2
# 895                     /werk_nl/werknemer/mijn_werkmap       89        2
# 921   /portal/page/portal/werk_nl/werknemer/uitkerin...       82        2
# 929   /portal/page/portal/werk_nl/werknemer/sollicit...       80        1
# 949   /werk_nl/werknemer/mijn_werkmap/doorgeven/take...       77        1
# 1000                    /werk_nl/werknemer/mijn_werkmap       71        1
# 1003                         /werk_nl/werknemer/werkmap       71        1
# 1067                            /werk_nl/werknemer/home       63        1
# 1124    /werk_nl/werknemer/mijn_werkmap/doorgeven/taken       57        1
# 1143                    /werk_nl/werknemer/over-werk-nl       55        1
# 1148  /werk_nl/werknemer/mijn_werkmap/werk-zoeken/mi...       55        1
# 1170          /werk_nl/werknemer/uitkering-aanvragen/ww       53        1
# 1196    /werk_nl/werknemer/mijn_werkmap/tip-van-de-week       52        1
# 1220  /werk_nl/werknemer/solliciteren/solliciteren-w...       50        1
# 1234  /portal/page/portal/werk_nl/werknemer/sollicit...       50        1
# 1251  /werk_nl/werknemer/mijn_werkmap/inschrijving/m...       49        1
# 1265          /werk_nl/werknemer/contact/email_uw_vraag       47        1
# 1290         /portal/pls/portal/!PORTAL.wwpob_smd.login       46        1
# 1327                               /xpsimage/wdo_014546       44        1
# 1349  /werk_nl/werknemer/solliciteren/ontwikkel-uzel...       42        1
# 1361  /werk_nl/werknemer/solliciteren/solliciteren-w...       42        1
# 1362  /werk_nl/werknemer/mijn_werkmap/postvak/mijn_b...       42        1
# 1366                            /werk_nl/werknemer/home       41        1
# 1381  /werk_nl/werknemer/solliciteren/ontwikkel-uzel...       41        1
#
#        dif         fac
# 88    4322  541.250000
# 97    3756   88.348837
# 179   1553  518.666667
# 222   1067  107.700000
# 232   1016  204.200000
# 237    978  979.000000
# 314    567   41.500000
# 366    432  433.000000
# 371    418  105.500000
# 379    399  200.500000
# 451    305  306.000000
# 454    300  101.000000
# 457    296   60.200000
# 483    263  132.500000
# 514    234  118.000000
# 534    210   53.500000
# 604    174   88.000000
# 677    140   71.000000
# 696    132   45.000000
# 699    132   67.000000
# 703    130   44.333333
# 707    129   44.000000
# 715    129   65.500000
# 736    123  124.000000
# 770    113   57.500000
# 780    109   55.500000
# 819    101   51.500000
# 843     98   99.000000
# 849     96   97.000000
# 858     93   47.500000
# 895     87   44.500000
# 921     80   41.000000
# 929     79   80.000000
# 949     76   77.000000
# 1000    70   71.000000
# 1003    70   71.000000
# 1067    62   63.000000
# 1124    56   57.000000
# 1143    54   55.000000
# 1148    54   55.000000
# 1170    52   53.000000
# 1196    51   52.000000
# 1220    49   50.000000
# 1234    49   50.000000
# 1251    48   49.000000
# 1265    46   47.000000
# 1290    45   46.000000
# 1327    43   44.000000
# 1349    41   42.000000
# 1361    41   42.000000
# 1362    41   42.000000
# 1366    40   41.000000
# 1381    40   41.000000

# %%
def label_sessions(_df:pd.DataFrame, _patterns:pd.DataFrame) -> pd.DataFrame:
  df = _df.copy()
  patterns = _patterns.copy()
  # create consecutive_1 and consecutive_2 columns
  df['consecutive_1'] = df.groupby('SessionID')['Activity'].shift(periods=-1).fillna('end')
  # drop rows where Activity == consecutive_1
  df = df[df['Activity'] != df['consecutive_1']]
  df['consecutive_2'] = df.groupby('SessionID')['Activity'].shift(periods=-2).fillna('end')
  
  merged = pd.merge(df, patterns, left_on=['Activity','consecutive_1'], right_on=['Activity_1_x','Activity_0_x'], how='inner',indicator='Anomaly')
  merged['Anomaly'] = np.where(merged.Anomaly == 'both', True, False)
  
  return merged

# %%
sessions = label_sessions(base_df, patters_df)
len(sessions)
# Out:
# 161

# %%
sess = sessions['SessionID'].unique()
len(sess)
# Out:
# 159

# %%
labeled_df = base_df.copy()
labeled_df["anomaly"] = base_df["SessionID"].apply(lambda x: x in sess)

# %%
import random


def label_80(ids:list[int]) -> list[int]:
  sample = random.sample(ids,k=int(0.8*len(ids)))
  return sample

sample = label_80(list(sess))
len(sample)
  
labeled_sample = base_df.copy()
labeled_sample["anomaly"] = labeled_sample["SessionID"].apply(lambda x: x in sample)
labeled_sample.to_csv(f"./labeled_data/Swapped_Sample.csv",index=False)

# %%
# # save in csv
# labeled_df.to_csv(f"./labeled_data/Swapped.csv",index=False)
# patters_df.to_csv(f"./gen_patterns/Swapped.csv",index=False)
